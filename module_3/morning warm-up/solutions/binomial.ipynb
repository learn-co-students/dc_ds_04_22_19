# %% [markdown]
# # weekend fun - week 3

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# 1. Create binomial distribution
# Plot (once with matplotlib once with seaborn) and play with parameters to get normal dist. 

bino = np.random.binomial(40, 0.5, 800)

plt.hist(bino)

# %%
sns.distplot(bino)

# %%
# [optional] 2. Central limit theorem from binomial distribution
# reminder: binomial is a sum of bernouli dist. variables
# can you explain why will the plot look like normal? discuss with a peer
